# %% [markdown]
# https://app.flourish.studio/visualisation/1571387/edit

# %%
import pandas as pd

df = pd.read_csv('covid_19_clean_complete.csv')

df = df.groupby(['Date', 'Country/Region'])['Confirmed'].sum().reset_index()

df['Date'] = pd.to_datetime(df['Date'])

df = df.sort_values('Date')

df.head()
# Out:
#           Date Country/Region  Confirmed
# 0   2020-01-22    Afghanistan          0
# 120 2020-01-22          Nepal          0
# 121 2020-01-22    Netherlands          0
# 122 2020-01-22    New Zealand          0
# 123 2020-01-22      Nicaragua          0

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Country/Region            object
# Confirmed                  int64
# dtype: object

# %%
df = df.pivot(index='Country/Region', columns='Date', values='Confirmed').reset_index()
df.head()
# Out:
# Date Country/Region  2020-01-22 00:00:00  2020-01-23 00:00:00  \
# 0       Afghanistan                    0                    0
# 1           Albania                    0                    0
# 2           Algeria                    0                    0
# 3           Andorra                    0                    0
# 4            Angola                    0                    0
#
# Date  2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-30 00:00:00  ...  2020-05-24 00:00:00  2020-05-25 00:00:00  \
# 0                       0  ...                10582                11173
# 1                       0  ...                  998                 1004
# 2                       0  ...                 8306                 8503
# 3                       0  ...                  762                  763
# 4                       0  ...                   69                   70
#
# Date  2020-05-26 00:00:00  2020-05-27 00:00:00  2020-05-28 00:00:00  \
# 0                   11831                12456                13036
# 1                    1029                 1050                 1076
# 2                    8697                 8857                 8997
# 3                     763                  763                  763
# 4                      70                   71                   74
#
# Date  2020-05-29 00:00:00  2020-05-30 00:00:00  2020-05-31 00:00:00  \
# 0                   13659                14525                15205
# 1                    1099                 1122                 1137
# 2                    9134                 9267                 9394
# 3                     764                  764                  764
# 4                      81                   84                   86
#
# Date  2020-06-01 00:00:00  2020-06-02 00:00:00
# 0                   15750                16509
# 1                    1143                 1164
# 2                    9513                 9626
# 3                     765                  844
# 4                      86                   86
#
# [5 rows x 134 columns]

# %%
df.to_csv('flurish_data.csv')
