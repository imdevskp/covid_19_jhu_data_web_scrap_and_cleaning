# %%
import pandas as pd

df = pd.read_csv('covid_19_clean_complete.csv')

df = df.groupby(['Date', 'Country/Region'])['Confirmed'].sum().reset_index()

df['Date'] = pd.to_datetime(df['Date'])

df = df.sort_values('Date')

df.head()
# Out:
#           Date Country/Region  Confirmed
# 0   2020-01-22    Afghanistan          0
# 120 2020-01-22          Nepal          0
# 121 2020-01-22    Netherlands          0
# 122 2020-01-22    New Zealand          0
# 123 2020-01-22      Nicaragua          0

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Country/Region            object
# Confirmed                  int64
# dtype: object

# %%
df = df.pivot(index='Country/Region', columns='Date', values='Confirmed').reset_index()
df.head()
# Out:
# Date Country/Region  2020-01-22 00:00:00  2020-01-23 00:00:00  \
# 0       Afghanistan                    0                    0
# 1           Albania                    0                    0
# 2           Algeria                    0                    0
# 3           Andorra                    0                    0
# 4            Angola                    0                    0
#
# Date  2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-30 00:00:00  ...  2020-05-16 00:00:00  2020-05-17 00:00:00  \
# 0                       0  ...                 6402                 6664
# 1                       0  ...                  933                  946
# 2                       0  ...                 6821                 7019
# 3                       0  ...                  761                  761
# 4                       0  ...                   48                   48
#
# Date  2020-05-18 00:00:00  2020-05-19 00:00:00  2020-05-20 00:00:00  \
# 0                    7072                 7653                 8145
# 1                     948                  949                  964
# 2                    7201                 7377                 7542
# 3                     761                  761                  762
# 4                      50                   52                   52
#
# Date  2020-05-21 00:00:00  2020-05-22 00:00:00  2020-05-23 00:00:00  \
# 0                    8676                 9216                 9998
# 1                     969                  981                  989
# 2                    7728                 7918                 8113
# 3                     762                  762                  762
# 4                      58                   60                   61
#
# Date  2020-05-24 00:00:00  2020-05-25 00:00:00
# 0                   10582                11173
# 1                     998                 1004
# 2                    8306                 8503
# 3                     762                  763
# 4                      69                   70
#
# [5 rows x 126 columns]

# %%
df.to_csv('flurish_data.csv')
