# %%
import pandas as pd

df = pd.read_csv('covid_19_clean_complete.csv')

df = df.groupby(['Date', 'Country/Region'])['Confirmed'].sum().reset_index()

df['Date'] = pd.to_datetime(df['Date'])

df = df.sort_values('Date')

df.head()
# Out:
#           Date Country/Region  Confirmed
# 0   2020-01-22    Afghanistan          0
# 120 2020-01-22    Netherlands          0
# 121 2020-01-22    New Zealand          0
# 122 2020-01-22      Nicaragua          0
# 123 2020-01-22          Niger          0

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Country/Region            object
# Confirmed                  int64
# dtype: object

# %%
df = df.pivot(index='Country/Region', columns='Date', values='Confirmed').reset_index()
df.head()
# Out:
# Date Country/Region  2020-01-22 00:00:00  2020-01-23 00:00:00  \
# 0       Afghanistan                    0                    0
# 1           Albania                    0                    0
# 2           Algeria                    0                    0
# 3           Andorra                    0                    0
# 4            Angola                    0                    0
#
# Date  2020-01-24 00:00:00  2020-01-25 00:00:00  2020-01-26 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-27 00:00:00  2020-01-28 00:00:00  2020-01-29 00:00:00  \
# 0                       0                    0                    0
# 1                       0                    0                    0
# 2                       0                    0                    0
# 3                       0                    0                    0
# 4                       0                    0                    0
#
# Date  2020-01-30 00:00:00  ...  2020-04-27 00:00:00  2020-04-28 00:00:00  \
# 0                       0  ...                 1703                 1828
# 1                       0  ...                  736                  750
# 2                       0  ...                 3517                 3649
# 3                       0  ...                  743                  743
# 4                       0  ...                   27                   27
#
# Date  2020-04-29 00:00:00  2020-04-30 00:00:00  2020-05-01 00:00:00  \
# 0                    1939                 2171                 2335
# 1                     766                  773                  782
# 2                    3848                 4006                 4154
# 3                     743                  745                  745
# 4                      27                   27                   30
#
# Date  2020-05-02 00:00:00  2020-05-03 00:00:00  2020-05-04 00:00:00  \
# 0                    2469                 2704                 2894
# 1                     789                  795                  803
# 2                    4295                 4474                 4648
# 3                     747                  748                  750
# 4                      35                   35                   35
#
# Date  2020-05-05 00:00:00  2020-05-06 00:00:00
# 0                    3224                 3392
# 1                     820                  832
# 2                    4838                 4997
# 3                     751                  751
# 4                      36                   36
#
# [5 rows x 107 columns]

# %%
df.to_csv('flurish_data.csv')
